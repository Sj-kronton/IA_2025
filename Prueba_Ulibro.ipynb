# %% [markdown]
# <a href="https://colab.research.google.com/github/Sj-kronton/IA_2025/blob/main/Prueba_Ulibro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ulibro

# %% [markdown]
# ![IMG20250825150837.jpg](data:image/jpeg;base64,...)
